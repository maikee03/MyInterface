# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\maike\anaconda3\envs\generalworkingenvironment\lib\site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in c:\users\maike\anaconda3\envs\generalworkingenvironment\lib\site-packages (from plotly) (25.0)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.9 MB 11.8 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 12.0 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.4 MB/s  0:00:00
# Installing collected packages: plotly
# Successfully installed plotly-6.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# Input sliders
income = st.slider("Monthly Income", 0, 5000, 2000)
rent = st.slider("Rent", 0, 2000, 800)
groceries = st.slider("Groceries", 0, 1000, 250)
transport = st.slider("Transport", 0, 500, 60)

# Compute totals
expenses = rent + groceries + transport
savings = income - expenses

st.metric("Total Expenses", expenses)
st.metric("Savings", savings)

# Create a chart
df = pd.DataFrame({
    "Category": ["Rent", "Groceries", "Transport", "Savings"],
    "Amount": [rent, groceries, transport, savings]
})
fig = px.pie(df, names='Category', values='Amount', title="Monthly Budget")
st.plotly_chart(fig)
# Out:
# 2025-11-24 20:46:48.478 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:48.481 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:48.482 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:48.484 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.198
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Maike\anaconda3\envs\GeneralWorkingEnvironment\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-24 20:46:49.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:49.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:52.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:52.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:52.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:52.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 20:46:52.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
streamlit run c:\Users\Maike\anaconda3\envs\GeneralWorkingEnvironment\Lib\site-packages\ipykernel_launcher.py
# Out:
#   Cell In[6], line 1
#     streamlit run c:\Users\Maike\anaconda3\envs\GeneralWorkingEnvironment\Lib\site-packages\ipykernel_launcher.py
#               ^
# SyntaxError: invalid syntax
